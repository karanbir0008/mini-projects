# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # loading data from csv file #

# %%
sonar_data = pd.read_csv("sonar_data.csv",header = None)
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %% [markdown]
# # analysis of the data #

# %%
sonar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
sonar_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %% [markdown]
# # split the data

# %%
x = sonar_data.drop(columns = 60,axis = 1)
y = sonar_data[60]

# %%
x.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      50      51      52      53      54      55      56  \
# 0  0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#        57      58      59
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# ...

# %%
y.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: 60, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state = 42)

# %%
x_train.shape
# Out:
# (187, 60)

# %%
x_test.shape
# Out:
# (21, 60)

# %% [markdown]
# # model training #

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # testing the model and dfinding accuracy #

# %%
test_result = model.predict(x_test)
print(test_result)
# Out:
# ['M' 'R' 'R' 'R' 'M' 'M' 'M' 'M' 'R' 'M' 'M' 'R' 'R' 'M' 'M' 'M' 'M' 'M'
#  'M' 'R' 'M']

# %%
accuracy_for_test_result = accuracy_score(y_test,test_result)

# %%
print(f"the accuracy of our model comes out to be : {int(accuracy_for_test_result*100)}% ")
# Out:
# the accuracy of our model comes out to be : 85%

# %%
accuracy_for_train_data = accuracy_score(y_train,model.predict(x_train))
print(accuracy_for_train_data)
# Out:
# 0.8235294117647058

# %% [markdown]
# # making a predictive system #

# %%
input_data = list(x_train.iloc[6])
print(input_data)
# Out:
# [0.0352, 0.0116, 0.0191, 0.0469, 0.0737, 0.1185, 0.1683, 0.1541, 0.1466, 0.2912, 0.2328, 0.2237, 0.247, 0.156, 0.3491, 0.3308, 0.2299, 0.2203, 0.2493, 0.4128, 0.3158, 0.6191, 0.5854, 0.3395, 0.2561, 0.5599, 0.8145, 0.6941, 0.6985, 0.866, 0.593, 0.3664, 0.675, 0.8697, 0.7837, 0.7552, 0.5789, 0.4713, 0.1252, 0.6087, 0.7322, 0.5977, 0.3431, 0.1803, 0.2378, 0.3424, 0.2303, 0.0689, 0.0216, 0.0469, 0.0426, 0.0346, 0.0158, 0.0154, 0.0109, 0.0048, 0.0095, 0.0015, 0.0073, 0.0067]

# %%
input_array = np.array(input_data)
answer = model.predict(input_array.reshape(1,-1))

# %%
print(type(answer),answer.shape,answer[0])
# Out:
# <class 'numpy.ndarray'> (1,) R
